# %% [markdown]
# # Instructions and Requirements:
# ## Instructions:
# *   This week students will have first portfollio projects,as describe in the task sheets.
# *   Goal is to make students friendly with data analyitcs task, and also measure the students current understanding on various topics and task instructed on the Lecture, Tutorial and Workshops.
# *   Please be advised it's a graded task, deadline for this is your week-7 workshops.
# ## Requirements:
#     *   Notebook Environment(Juopyter or Google Colab)

# %% [markdown]
# #Week 3 Outline
# *   Gentle Introduction to various Feature Selection Algorithm:
#   *   Implement Feature selection algorithm with the help of SK-Learn.
# *   Gentle Introduction to Steps in Data Analytics Task
#   *   Implement k-NN and Random Forest Classifier on original dataset.
#   *   Implement Feature selection and compare the accuracy with above.
#   *   Comparative analysis with and without Feature Selection.
#
# *   Datasets for this work:
#   *   Breast Cancer Wisconsin (Prognostic) Data Set

# %% [markdown]
# #Dataset Understanding and Visualization
# # *   Tasks:
# 1.   Necessary Imports
# 2.   Load the datasets using pandas,
# 3.   Display top 5 datasets,
# 4.   How many feature sets are there in datasets, what are the data type?
# 5.   Identify Features and Target Variables,

# %%
# Load the dataset using pandas:
import pandas as pd
import numpy as np
dataset = pd.read_csv(r'D:\\jeshmi\\AI\\Breast Cancer Wisconsin (Prognostic) Data Set.csv')

# %%
dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   perimeter_mean           569 non-null    float64
#  3   area_mean                569 non-null    float64
#  4   smoothness_mean          569 non-null    float64
#  5   compactness_mean         569 non-null    float64
#  6   concavity_mean           569 non-null    float64
#  7   concave points_mean      569 non-null    float64
#  8   symmetry_mean            569 non-null    float64
#  9   fractal_dimension_mean   569 non-null    float64
#  10  radius_se                569 non-null    float64
#  11  texture_se               569 non-null    float64
#  12  perimeter_se             569 non-null    float64
# ...

# %%
#Seperate Features and Targets
# Your Code Here
features = dataset.iloc[:,:-1]
target = dataset.iloc[:,-1:]

# %%
# Code Test 
assert features.shape[0] == target.shape[0] , "Number of datasets in featurees and Target variables are not equal"

# %% [markdown]
# # Model Building:
#  <font color="red"> $\bf{Tasks} $
# 1.   Split the datasets between train and test set

# %%
# import necessary  library from sklearn
from sklearn.model_selection import train_test_split
# Your code here
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.20, random_state=42)

# %% [markdown]
# ##**KNN - K Nearest Neighbors***
#
# In pattern recognition, the k-nearest neighbors algorithm (k-NN) is a non-parametric method used for classification and regression. In both cases, the input consists of the k closest training examples in the feature space. The output depends on whether k-NN is used for classification or regression:
#
# > * In k-NN classification, the output is a class membership. An object is classified by a plurality vote of its neighbors, with the object being assigned to the class most common among its k nearest neighbors (k is a positive integer, typically small). If k = 1, then the object is simply assigned to the class of that single nearest neighbor.
#
# *from [Wikipedia](https://en.wikipedia.org/wiki/K-nearest_neighbors_algorithm).

# %% [markdown]
#  ## **Instantiating the KNN Algorithm**
#
# The KNN Classifier (KNeighborsClassifier) is imported from Scikit-learn.

# %%
# Your Code Here:
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# ## **Trainning the KNN algorithm**
#
# At this step the algorithm is trained to estimate the best representative function for the data, according to the parameters being used.
#
# **Fit** is the method to adjust the classifier to the data.

# %%
knn.fit(X_train,y_train)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Accuracy
# Print the Classification Report for your Model Performance.

# %%
y_pred = knn.predict(X_test)

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.96      0.94        71
#            M       0.93      0.88      0.90        43
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.92      0.92       114
# weighted avg       0.93      0.93      0.93       114

# %% [markdown]
# # Cross-Validation
# Hyper-parameter tuning with cross validation as implemented from last week.

# %% [markdown]
# ## GridSearch CV
#  <font color="Yellow"> $\bf{To-Do} $
# 1.   Identify the hyper-parameters for k-NN
# 2.   Implement Grid-Search CV to find best hyperparameters.
#   *   Make a dicitionary of hyper-parameters that you want to tune
#   *   List item

# %%
# Your code here
from sklearn.model_selection import GridSearchCV
leaf_size = list(range(1,50))
n_neighbors = list(range(1,10))
p=[1,2]

# %%
hyperparameters = dict(leaf_size=leaf_size,n_neighbors=n_neighbors,p=p)

# %%
knn = KNeighborsClassifier()
knn_cv= GridSearchCV(knn,hyperparameters,cv=10)
knn_cv.fit(X_train,y_train)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
knn_cv.best_score_
# Out:
# 0.936183574879227

# %%
knn_cv.best_params_
# Out:
# {'leaf_size': 1, 'n_neighbors': 7, 'p': 1}

# %% [markdown]
# # Feature Selection
# In machine learning and statistics, feature selection, also known as ***variable selection, attribute selection*** or **variable subset selection**, is the process of selecting a subset of relevant features (variables, predictors) for use in model construction.
# The central premise when using a feature selection technique is that the data contains some features that are either redundant or irrelevant, and can thus be removed without incurring much loss of information.
# There are three main categories of feature selection algorithms:
# 1.   Filter Methods
# 2.   Wrapper Methods
# 3.   Embedded Methods
# (Source: from Wkikipedia)

# %% [markdown]
# ## Filter Methods
# This methods uses univariate statistics to rank the features based on there relevance, only high rank featues are then kept for further model building.
# Any statistical methods can be used; but some common methods used are:
#
#     *   Correlation Coefficients
#     *   Variance Threshold
#     *   Information Gain
#
#  *   Can you think about any such methods that can be used?
#
#  <font color="Green"> $\bf{SelectKBest}$ From sickit learn
# 1.   select features according to the k highest scores.
#         *   Hints:
#         scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest
#         *   [link text](https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html)
#             *   use score function to be "chi"

# %%
# Re-evaluate Datasets:
dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
features.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# necessary imports:
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# Your Code Here(Uncomment best_features and write your code):
best_features = SelectKBest(score_func=chi2, k=7)
fit = best_features.fit(features, target) # Run score function on (X, y) and get the appropriate features.
select_kbest = best_features.fit_transform(features, target)

# %%
select_kbest
# Out:
# array([[  17.99 ,  122.8  , 1001.   , ...,   25.38 ,  184.6  , 2019.   ],
#        [  20.57 ,  132.9  , 1326.   , ...,   24.99 ,  158.8  , 1956.   ],
#        [  19.69 ,  130.   , 1203.   , ...,   23.57 ,  152.5  , 1709.   ],
#        ...,
#        [  16.6  ,  108.3  ,  858.1  , ...,   18.98 ,  126.7  , 1124.   ],
#        [  20.6  ,  140.1  , 1265.   , ...,   25.74 ,  184.6  , 1821.   ],
#        [   7.76 ,   47.92 ,  181.   , ...,    9.456,   59.16 ,  268.6  ]])

# %%
select_kbest.dtype
# Out:
# dtype('float64')

# %%
# Storing features and there score value in dataframes:
dfscores = pd.DataFrame(fit.scores_)
dfcoloumns = pd.DataFrame(features.columns)
# Concat two dataframes for better visualization
features_scores = pd.concat([dfcoloumns, dfscores], axis = 1)
features_scores.columns = ["Features", "Scores"] # naming the dataframe Coloumns
# saving dataframe to csv
name = "feature_scores"
features_scores.to_csv(name)
features_scores
# Out:
#                    Features         Scores
# 0               radius_mean     266.104917
# 1              texture_mean      93.897508
# 2            perimeter_mean    2011.102864
# 3                 area_mean   53991.655924
# 4           smoothness_mean       0.149899
# 5          compactness_mean       5.403075
# 6            concavity_mean      19.712354
# 7       concave points_mean      10.544035
# 8             symmetry_mean       0.257380
# 9    fractal_dimension_mean       0.000074
# 10                radius_se      34.675247
# 11               texture_se       0.009794
# 12             perimeter_se     250.571896
# 13                  area_se    8758.504705
# 14            smoothness_se       0.003266
# 15           compactness_se       0.613785
# 16             concavity_se       1.044718
# 17        concave points_se       0.305232
# 18              symmetry_se       0.000080
# 19     fractal_dimension_se       0.006371
# 20             radius_worst     491.689157
# ...

# %%
# Drop the unwanted features i.e. only keep top k features:
# This method if you want to store your features in array:
select_kbest = best_features.fit_transform(features, target)
# How to create csv/dataframe with only selected features:
index_kbest = best_features.get_support() # provides the index for kbest features
selected_features = features.loc[:,index_kbest].columns.tolist()
#selected_features
#Bonous Task:
# Drop except this list from dataframe:
# Your Code Here

selected = features.drop(['texture_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','smoothness_se','compactness_se','concavity_se','concave points_se','symmetry_se','fractal_dimension_se','texture_worst','smoothness_worst','compactness_worst','concavity_worst','concave points_worst','symmetry_worst','fractal_dimension_worst'],axis=1)

# %%
selected_features
# Out:
# ['radius_mean',
#  'perimeter_mean',
#  'area_mean',
#  'area_se',
#  'radius_worst',
#  'perimeter_worst',
#  'area_worst']

# %%
selected
# Out:
#      radius_mean  perimeter_mean  area_mean  area_se  radius_worst  \
# 0          17.99          122.80     1001.0   153.40        25.380
# 1          20.57          132.90     1326.0    74.08        24.990
# 2          19.69          130.00     1203.0    94.03        23.570
# 3          11.42           77.58      386.1    27.23        14.910
# 4          20.29          135.10     1297.0    94.44        22.540
# ..           ...             ...        ...      ...           ...
# 564        21.56          142.00     1479.0   158.70        25.450
# 565        20.13          131.20     1261.0    99.04        23.690
# 566        16.60          108.30      858.1    48.55        18.980
# 567        20.60          140.10     1265.0    86.22        25.740
# 568         7.76           47.92      181.0    19.15         9.456
#
#      perimeter_worst  area_worst
# 0             184.60      2019.0
# 1             158.80      1956.0
# 2             152.50      1709.0
# ...

# %%
assert select_kbest.shape[0] == target.shape[0], "Number of data in feature must be equal with target"

# %%
X_train, X_test, y_train, y_test = train_test_split(selected, target, test_size=0.20, random_state=42)

# %% [markdown]
# ### Implement K-NN with only selected Features

# %%
knn2 = KNeighborsClassifier(n_neighbors=7)
knn2.fit(X_train,y_train)
y_pred = knn2.predict(X_test)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.99      0.97        71
#            M       0.97      0.91      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# ###<font color="Yellow"> $\bf{Bonous-Task} $
# 1.   Use Correlation coefficient to drop some features.
#         *   Hints:
#         *   First Cor-relation matrix to find the corealtion of each feature with each other
#             *   pandas.corr function may be helpful
#         *   Drop all the coloumns with Correlation coefficient above 0.9

# %%
# Recheck my dataset:
dataset.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
# Check features 
features.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
#calculate correlation:
    #Hint: --.corr() function of pandas
# Your Code Here:
features_corr = features.corr()
features_corr.head()
# Out:
#                  radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean         1.000000      0.323782        0.997855   0.987357
# texture_mean        0.323782      1.000000        0.329533   0.321086
# perimeter_mean      0.997855      0.329533        1.000000   0.986507
# area_mean           0.987357      0.321086        0.986507   1.000000
# smoothness_mean     0.170581     -0.023389        0.207278   0.177028
#
#                  smoothness_mean  compactness_mean  concavity_mean  \
# radius_mean             0.170581          0.506124        0.676764
# texture_mean           -0.023389          0.236702        0.302418
# perimeter_mean          0.207278          0.556936        0.716136
# area_mean               0.177028          0.498502        0.685983
# smoothness_mean         1.000000          0.659123        0.521984
#
#                  concave points_mean  symmetry_mean  fractal_dimension_mean  \
# ...

# %%
# Better visualizarion with SNS Heat map:
# Hint: Use seaborn library heatmap function
import seaborn as sns
sns.set(rc={'figure.figsize':(20,20)})
#Your Code Here
# plot a heatmap
sns.heatmap(features_corr, cbar = True, annot=True, fmt= '.2f',annot_kws={'size': 10},
           xticklabels= features.columns, yticklabels= features.columns,
           cmap= 'viridis')
sns.heatmap(features_corr)
# Out:
# <AxesSubplot:>

# %%
# Drop all the coloumns above 0.9
threshold = 0.9
# Your code here:
# Create an boolean array equal to the size of number of coloumns 
coloumns = np.full((features_corr.shape[0]),True, dtype=bool)
# Implement a for loop, that checks the value of correlation coefficients and compares with the threshold if high change th value of coloumn to false:
for i in range(features_corr.shape[0]):
  for j in range(i+1, features_corr.shape[0]):
    if features_corr.iloc[i,j] >= threshold:
      if coloumns[j]:
        coloumns[j] = False
selected_coloumns = features.columns[coloumns]
selected_coloumns
features_selected = features[selected_coloumns]

# %%
assert len(selected_coloumns) == 20, "Test did not pass"
features_selected.head()
# Out:
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
# 3        11.42         20.38          0.14250           0.28390
# 4        20.29         14.34          0.10030           0.13280
#
#    concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0          0.3001         0.2419                 0.07871     1.0950
# 1          0.0869         0.1812                 0.05667     0.5435
# 2          0.1974         0.2069                 0.05999     0.7456
# 3          0.2414         0.2597                 0.09744     0.4956
# 4          0.1980         0.1809                 0.05883     0.7572
#
#    texture_se  smoothness_se  compactness_se  concavity_se  concave points_se  \
# 0      0.9053       0.006399         0.04904       0.05373            0.01587
# ...

# %%
features_selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   smoothness_mean          569 non-null    float64
#  3   compactness_mean         569 non-null    float64
#  4   concavity_mean           569 non-null    float64
#  5   symmetry_mean            569 non-null    float64
#  6   fractal_dimension_mean   569 non-null    float64
#  7   radius_se                569 non-null    float64
#  8   texture_se               569 non-null    float64
#  9   smoothness_se            569 non-null    float64
#  10  compactness_se           569 non-null    float64
#  11  concavity_se             569 non-null    float64
#  12  concave points_se        569 non-null    float64
# ...

# %% [markdown]
# ### Implement k-NN only with selected features:

# %%
# Your Code Here
X_train, X_test, y_train, y_test = train_test_split(features_selected, target, test_size=0.20, random_state=42)

# %%
assert features_selected.shape[0] == target.shape[0],"Number of data in feature must be equal with target"

# %%
knn3 = KNeighborsClassifier(n_neighbors=3)
knn3.fit(X_train,y_train)
y_pred = knn3.predict(X_test)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.94      0.94        71
#            M       0.90      0.88      0.89        43
#
#     accuracy                           0.92       114
#    macro avg       0.92      0.91      0.92       114
# weighted avg       0.92      0.92      0.92       114

# %% [markdown]
# ## Wrapper Methods
# The feature Selection is based on a specific machine learning algorithms, we want to implement with the dataset in hand. It is a greedy approach,which selects best combinations of features against the evaluation metrics.There are multiple ways we can implement based on how we make the combinations. We will only look into following two:
# 1.   Forward Selection
# 2.   Backward Elimination
# *   Please feel free to explore more:

# %% [markdown]
# ### Forward Selection
# > We will use SequentialFeatureSelector library from sickit learn.
# *   [sickitlearn link](https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_diabetes.html#sphx-glr-auto-examples-feature-selection-plot-select-from-model-diabetes-py)

# %%
# First import the machine learning algorithm we want to implement
from sklearn.neighbors import KNeighborsClassifier
knn_fs = KNeighborsClassifier(n_neighbors=9)

# %%
# Necessary Imports:
from sklearn.feature_selection import SequentialFeatureSelector
sfs_forward = SequentialFeatureSelector(knn_fs, n_features_to_select=15, direction="forward")
sfs_forward.fit(features, target)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# ...

# %%
columns_names = np.array(features.columns)
print("Features selected by forward sequential selection: "f"{columns_names[sfs_forward.get_support()]}")
# Out:
# Features selected by forward sequential selection: ['smoothness_mean' 'concavity_mean' 'concave points_mean' 'symmetry_mean'
#  'fractal_dimension_mean' 'radius_se' 'smoothness_se' 'compactness_se'
#  'concavity_se' 'concave points_se' 'symmetry_se' 'fractal_dimension_se'
#  'smoothness_worst' 'concave points_worst' 'fractal_dimension_worst']

# %% [markdown]
# ### Backward Elimination

# %%
sfs_backward = SequentialFeatureSelector(knn_fs, n_features_to_select=15, direction="backward")
sfs_backward.fit(features, target)

# %%
print("Features selected by backward sequential selection: "f"{columns_names[sfs_backward.get_support()]}")
# Out:
# Features selected by backward sequential selection: ['perimeter_mean' 'area_mean' 'area_se' 'symmetry_se'
#  'fractal_dimension_se' 'radius_worst' 'texture_worst' 'perimeter_worst'
#  'area_worst' 'smoothness_worst' 'compactness_worst' 'concavity_worst'
#  'concave points_worst' 'symmetry_worst' 'fractal_dimension_worst']

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   radius_mean              569 non-null    float64
#  1   texture_mean             569 non-null    float64
#  2   perimeter_mean           569 non-null    float64
#  3   area_mean                569 non-null    float64
#  4   smoothness_mean          569 non-null    float64
#  5   compactness_mean         569 non-null    float64
#  6   concavity_mean           569 non-null    float64
#  7   concave points_mean      569 non-null    float64
#  8   symmetry_mean            569 non-null    float64
#  9   fractal_dimension_mean   569 non-null    float64
#  10  radius_se                569 non-null    float64
#  11  texture_se               569 non-null    float64
#  12  perimeter_se             569 non-null    float64
# ...

# %%
selected1 = features.drop(['radius_mean','texture_mean','smoothness_mean','compactness_mean','concavity_mean','concave points_mean','symmetry_mean','fractal_dimension_mean','radius_se','texture_se','perimeter_se','smoothness_se','compactness_se','concavity_se','concave points_se'],axis=1)

# %%
selected1
# Out:
#      perimeter_mean  area_mean  area_se  symmetry_se  fractal_dimension_se  \
# 0            122.80     1001.0   153.40      0.03003              0.006193
# 1            132.90     1326.0    74.08      0.01389              0.003532
# 2            130.00     1203.0    94.03      0.02250              0.004571
# 3             77.58      386.1    27.23      0.05963              0.009208
# 4            135.10     1297.0    94.44      0.01756              0.005115
# ..              ...        ...      ...          ...                   ...
# 564          142.00     1479.0   158.70      0.01114              0.004239
# 565          131.20     1261.0    99.04      0.01898              0.002498
# 566          108.30      858.1    48.55      0.01318              0.003892
# 567          140.10     1265.0    86.22      0.02324              0.006185
# 568           47.92      181.0    19.15      0.02676              0.002783
#
#      radius_worst  texture_worst  perimeter_worst  area_worst  \
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(selected1, target, test_size=0.20, random_state=42)

# %%
assert selected1.shape[0] == target.shape[0],"Number of data in feature must be equal with target"

# %%
knn_fs.fit(X_train,y_train)
y_pred = knn_fs.predict(X_test)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.99      0.97        71
#            M       0.97      0.91      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# ## Embedded Methods
# The main idea behind Embedded methods is to perform feature selection during model training, thus this mehods depends on choice of your algorithms, for example knn can not be use for this, as knn doesnot have any methods to measure the importance of features during training.
#   *   What about Decision Tree?
#   *   We will use ExtraTreeClassifier, you can also use RandomForest Classifier.

# %%
# Necessary Imports
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier(n_estimators=50)
clf = clf.fit(features, target)
clf.feature_importances_
# Out:
# <ipython-input-51-74b48a985c87>:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf = clf.fit(features, target)
# array([0.06926594, 0.01619629, 0.04947339, 0.05758116, 0.0154332 ,
#        0.02653715, 0.02793989, 0.08295857, 0.00652371, 0.00579967,
#        0.0237439 , 0.00516942, 0.02310061, 0.0226266 , 0.0073276 ,
#        0.00755719, 0.00466646, 0.00750215, 0.00617079, 0.00555476,
#        0.1121341 , 0.02392476, 0.1380883 , 0.0642182 , 0.01904854,
#        0.03716652, 0.0507464 , 0.05913124, 0.01366492, 0.01074855])

# %%
from sklearn.feature_selection import SelectFromModel
model = SelectFromModel(clf, prefit=True)
features_new = model.transform(features)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(

# %%
features_new.shape
# Out:
# (569, 10)

# %%
features_new
# Out:
# array([[1.799e+01, 1.228e+02, 1.001e+03, ..., 6.656e-01, 7.119e-01,
#         2.654e-01],
#        [2.057e+01, 1.329e+02, 1.326e+03, ..., 1.866e-01, 2.416e-01,
#         1.860e-01],
#        [1.969e+01, 1.300e+02, 1.203e+03, ..., 4.245e-01, 4.504e-01,
#         2.430e-01],
#        ...,
#        [1.660e+01, 1.083e+02, 8.581e+02, ..., 3.094e-01, 3.403e-01,
#         1.418e-01],
#        [2.060e+01, 1.401e+02, 1.265e+03, ..., 8.681e-01, 9.387e-01,
#         2.650e-01],
#        [7.760e+00, 4.792e+01, 1.810e+02, ..., 6.444e-02, 0.000e+00,
#         0.000e+00]])

# %%
X_train, X_test, y_train, y_test = train_test_split(features_new, target, test_size=0.20, random_state=42)

# %%
assert features_new.shape[0] == target.shape[0],"Number of data in feature must be equal with target"

# %%
knn4 = KNeighborsClassifier(n_neighbors=3)
knn4.fit(X_train,y_train)
y_pred = knn4.predict(X_test)
# Out:
# C:\Users\Asus\miniconda3\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.93      0.96      0.94        71
#            M       0.93      0.88      0.90        43
#
#     accuracy                           0.93       114
#    macro avg       0.93      0.92      0.92       114
# weighted avg       0.93      0.93      0.93       114
